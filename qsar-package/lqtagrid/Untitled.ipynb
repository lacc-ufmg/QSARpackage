# %%
import pybel

# %%
from numpy import empty,vstack

# %%
filename = "../../teste/output_dir/LQTAGridFiles/cks03.log"

# %%
pac = pybel.readfile("pdb","../../teste/output_dir/LQTAGridFiles/cks03_PAC_aligned.pdb")

# %%
pac
# Out:
# <generator object readfile.<locals>.filereader at 0x7f570c0b0b48>

# %%
X = empty((0,3))

# %%
for c in pac:
    print(len(c.atoms))
    for a in c.atoms:        
        X = vstack((X,a.coords))
# Out:
# 36
# 36
# 36
# 36

# %%
X
# Out:
# array([[18.37 , 17.32 , 22.624],
#        [14.687, 18.735, 19.681],
#        [15.839, 18.023, 20.052],
#        [14.7  , 20.092, 19.418],
#        [17.036, 20.014, 19.869],
#        [17.061, 18.655, 20.089],
#        [15.896, 20.801, 19.705],
#        [18.737, 17.773, 17.637],
#        [19.194, 17.845, 15.668],
#        [18.741, 19.493, 13.663],
#        [19.473, 18.315, 13.444],
#        [18.262, 19.957, 14.954],
#        [19.925, 18.136, 12.029],
#        [18.548, 16.907, 21.248],
#        [18.379, 17.952, 20.149],
#        [18.297, 17.482, 23.782],
#        [19.464, 17.043, 16.669],
#        [18.299, 18.936, 17.249],
#        [18.559, 19.014, 15.917],
#        [19.841, 17.473, 14.493],
#        [18.736, 17.243, 18.913],
#        [17.757, 21.036, 15.16 ],
#        [15.941, 22.529, 19.695],
#        [13.763, 18.184, 19.534],
#        [15.818, 16.938, 20.015],
#        [13.783, 20.648, 19.248],
#        [18.006, 20.468, 20.048],
#        [18.384, 20.14 , 12.87 ],
# ...

# %%
filename_parts = list(pac)[0].title.split('.')

# %%
import os

# %%
p = os.path.abspath(filename).split('.')

# %%
p[-2]
# Out:
# '/home/jpam/google_drive/UFMG/QSARpackage/teste/output_dir/LQTAGridFiles/cks03'

# %%
os.path.exists(p[-2]+"_PAC_aligned.pdb")
# Out:
# True

# %%
len(list(pac)[0].atoms)
# Out:
# 36

# %%
pac
# Out:
# <generator object readfile.<locals>.filereader at 0x7f570c0b0830>
